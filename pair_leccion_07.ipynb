# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

# %%
# ahora creamos la conexión con los argumentos:
try:
    cnxguay = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

    print(cnxguay)

except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)

# %%
mycursor = cnxguay.cursor()

# %%
query1 = """ 
SELECT COLUMN_NAME
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_SCHEMA = 'northwind' AND TABLE_NAME = 'customers';
"""

# %%
## ejecuta la consulta (QUERY)
mycursor.execute(query1)

# %%
columnas_customers = mycursor.fetchall()

# %%
columnas_customers
# Out:
# [('Address',),
#  ('City',),
#  ('CompanyName',),
#  ('ContactName',),
#  ('ContactTitle',),
#  ('Country',),
#  ('CustomerID',),
#  ('Fax',),
#  ('Phone',),
#  ('PostalCode',),
#  ('Region',)]

# %%
# Hay que hacer otra query para sacar donde salga en city london o seattle
query = """
SELECT *
FROM customers
WHERE city IN ("London", "Seattle");
"""

# %%
mycursor.execute(query)

# %%
cositas_ciudades = mycursor.fetchall()

# %%
cositas_ciudades
pd.DataFrame(cositas_ciudades)
# Out:
#       0                      1                  2                     3   \
# 0  AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1  BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2  CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3  EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4  NORTS            North/South     Simon Crowther       Sales Associate
# 5  SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6  WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                              4        5     6         7    8               9   \
# 0               120 Hanover Sq.   London  None   WA1 1DP   UK  (171) 555-7788
# 1             Fauntleroy Circus   London  None   EC2 5NT   UK  (171) 555-1212
# 2  Berkeley Gardens 12  Brewery   London  None   WX1 6LT   UK  (171) 555-2282
# ...

# %%
pd.DataFrame(cositas_ciudades, columns=columnas_customers)
# Out:
#   (Address,)                (City,)     (CompanyName,)        (ContactName,)  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                 (ContactTitle,) (Country,) (CustomerID,)    (Fax,) (Phone,)  \
# 0               120 Hanover Sq.     London          None   WA1 1DP       UK
# 1             Fauntleroy Circus     London          None   EC2 5NT       UK
# 2  Berkeley Gardens 12  Brewery     London          None   WX1 6LT       UK
# ...
