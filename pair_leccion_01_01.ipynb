# %% [markdown]
# # Ejercicio pair

# %% [markdown]
# Energía eléctrica --> url

# %%
import pandas as pd

# %%
import requests

# %%
url1 = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2012-12-31T23:59&time_trunc=month"

#ejemplo url completa que tenemos que ir rellenando: https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2014-01-01T00:00&end_date=2018-12-31T23:59&time_trunc=year

# %%
requests.get(url1)
# Out:
# <Response [200]>

# %%
llamada = requests.get(url1)

# %%
llamada.status_code
# Out:
# 200

# %%
llamada.content
# Out:
# b'{"data":{"type":"Generaci\\u00f3n por tecnolog\\u00eda","id":"gen1","attributes":{"title":"Generaci\\u00f3n por tecnolog\\u00eda","last-update":"2019-06-12T15:32:24.000+02:00","description":null},"meta":{"cache-control":{"cache":"HIT","expireAt":"2025-03-21T10:22:38"}}},"included":[{"type":"Hidr\\u00e1ulica","id":"10288","groupId":"1","attributes":{"title":"Hidr\\u00e1ulica","description":null,"color":"#0090d1","type":"Renovable","magnitude":null,"composite":false,"last-update":"2019-06-12T15:32:24.000+02:00","values":[{"value":5119512.38,"percentage":0.19976265684687228,"datetime":"2011-01-01T00:00:00.000+01:00"},{"value":2998051.279,"percentage":0.13054077867742991,"datetime":"2011-02-01T00:00:00.000+01:00"},{"value":3910363.276,"percentage":0.15741784652381913,"datetime":"2011-03-01T00:00:00.000+01:00"},{"value":3537937.995,"percentage":0.16467786027045764,"datetime":"2011-04-01T00:00:00.000+02:00"},{"value":2797500.027,"percentage":0.12856432984303148,"datetime":"2011-05-01T00:
# ...

# %%
llamada.json()
# Out:
# {'data': {'type': 'Generación por tecnología',
#   'id': 'gen1',
#   'attributes': {'title': 'Generación por tecnología',
#    'last-update': '2019-06-12T15:32:24.000+02:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2025-03-21T10:22:38'}}},
#  'included': [{'type': 'Hidráulica',
#    'id': '10288',
#    'groupId': '1',
#    'attributes': {'title': 'Hidráulica',
#     'description': None,
#     'color': '#0090d1',
#     'type': 'Renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2019-06-12T15:32:24.000+02:00',
#     'values': [{'value': 5119512.38,
#       'percentage': 0.19976265684687228,
#       'datetime': '2011-01-01T00:00:00.000+01:00'},
#      {'value': 2998051.279,
#       'percentage': 0.13054077867742991,
#       'datetime': '2011-02-01T00:00:00.000+01:00'},
#      {'value': 3910363.276,
#       'percentage': 0.15741784652381913,
#       'datetime': '2011-03-01T00:00:00.000+01:00'},
# ...

# %%
datos_energia = llamada.json()

# %%
type(datos_energia)
# Out:
# dict

# %%
len(datos_energia)
# Out:
# 2

# %%
datos_energia.keys() #ok, para saber cuales eran las keys del diccionario
# Out:
# dict_keys(['data', 'included'])

# %%
url2_años2013_2014 = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2013-01-01T00:00&end_date=2014-12-31T23:59&time_trunc=month"

# %%
requests.get(url2_años2013_2014)
# Out:
# <Response [200]>

# %%
llamada2 = requests.get(url2_años2013_2014) #nos sale sacando solo por dos años, por lo que habría que sacar variables por cada dos años

# %%
#nos da la solución cesar en clase para todos los años (pero recomienda hacerlo primero con un año)
#había que hacer un for para sacar los años y no poniéndolos a mano y después en vez de un print hay que ponerle la llamada/requests

# %%
for año in range(2011, 2025):
    url_todos_años = f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date={año}-01-01T00:00&end_date={año}-12-31T23:59&time_trunc=month"
    print(url_todos_años)
# Out:
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2012-01-01T00:00&end_date=2012-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2013-01-01T00:00&end_date=2013-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2014-01-01T00:00&end_date=2014-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2015-01-01T00:00&end_date=2015-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2016-01-01T00:00&end_date=2016-12-31T23:59&time_trunc=month
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2017-01-01T00:00&end_date=2017-12-31T23:59&time_trunc=month
# ...
